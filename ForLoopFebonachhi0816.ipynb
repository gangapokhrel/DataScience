# %% [markdown]
# <a href="https://colab.research.google.com/github/gangapokhrel/DataScience/blob/main/ForLoopFebonachhi0816.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#febonachi series
n=int
a=0
b=1
for i in range (0,10):
  c=a+b
  print (c,end='')
  a=b
  b=c
# Out:
# 123581321345589

# %%
# from IPython.testing import test
dict test_Results={'Rakesh':89,'Bonu:56,'Manu':12,'Biru':19, 'Ramu':91,'ghanu':99}
for keys, values in test_Results():
  if values >=95:
                print(keys,values,"grade = 'A+')
                elif values >=75:
                print(keys,values,"Grade A")
  print(keys,values)
  elif values >=50:
                      print (keys,values,"This is grade B")
                      elif values >=35:
                      print (keys,values, "this is fail")
                      else:
                      print('student:',keys,values,'Better luck nextime')
# Out:
#   File "<ipython-input-24-0162f973e0da>", line 2
#     dict test_Results={'Rakesh':89,'Bonu:56,'Manu':12,'Biru':19, 'Ramu':91,'ghanu':99}
#                                                                                  ^
# SyntaxError: unterminated string literal (detected at line 2)

# %% [markdown]
# Functions
# 1. built in functions
# 2. user defined functions
#
# Built in functions
# https://docs.python.org/3/library/functions.html

# %%
int1=1947
print(float(int1))
print(complex(int1))
print(bool(int1))
print (str(int1))
#print(list(int1))
#print(tuple(int1))
#print(set(int1))
#print(dict(int1))
# Out:
# 1947.0
# (1947+0j)
# True
# 1947

# %%
#decimal =>bin(),oct(),hex()
for i in range(0,100):
  print('Decimal:',i)
  print('Binary:',bin(i))
  print('Octa Decimal:',oct(i))
  print ('Hexa Decimal:',hex(i))
# Out:
# Decimal: 0
# Binary: 0b0
# Octa Decimal: 0o0
# Hexa Decimal: 0x0
# Decimal: 1
# Binary: 0b1
# Octa Decimal: 0o1
# Hexa Decimal: 0x1
# Decimal: 2
# Binary: 0b10
# Octa Decimal: 0o2
# Hexa Decimal: 0x2
# Decimal: 3
# Binary: 0b11
# Octa Decimal: 0o3
# Hexa Decimal: 0x3
# Decimal: 4
# Binary: 0b100
# Octa Decimal: 0o4
# Hexa Decimal: 0x4
# Decimal: 5
# Binary: 0b101
# Octa Decimal: 0o5
# Hexa Decimal: 0x5
# Decimal: 6
# Binary: 0b110
# Octa Decimal: 0o6
# Hexa Decimal: 0x6
# Decimal: 7
# Binary: 0b111
# Octa Decimal: 0o7
# Hexa Decimal: 0x7
# Decimal: 8
# Binary: 0b1000
# Octa Decimal: 0o10
# Hexa Decimal: 0x8
# Decimal: 9
# Binary: 0b1001
# Octa Decimal: 0o11
# Hexa Decimal: 0x9
# Decimal: 10
# Binary: 0b1010
# Octa Decimal: 0o12
# Hexa Decimal: 0xa
# Decimal: 11
# Binary: 0b1011
# Octa Decimal: 0o13
# Hexa Decimal: 0xb
# Decimal: 12
# Binary: 0b1100
# Octa Decimal: 0o14
# Hexa Decimal: 0xc
# Decimal: 13
# Binary: 0b1101
# Octa Decimal: 0o15
# Hexa Decimal: 0xd
# Decimal: 14
# ...

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
#user defined functions
def sum_of_two(a,b):
  return (a+b)
sum_of_two (1900,-1945)
# Out:
# -45
